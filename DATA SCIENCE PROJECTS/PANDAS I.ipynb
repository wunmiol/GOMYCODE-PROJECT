# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Popular_Baby_Names.txt')

# %%
data
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2               2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3               2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4               2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# ...              ...     ...                         ...                ...
# 11340           2016  FEMALE          BLACK NON HISPANIC            Saniyah
# 11341           2016  FEMALE          BLACK NON HISPANIC               Skye
# 11342           2016  FEMALE          BLACK NON HISPANIC              Tiana
# 11343           2016  FEMALE          BLACK NON HISPANIC             Violet
# 11344           2016  FEMALE          BLACK NON HISPANIC              Zahra
#
#        Count  Rank
# 0        119     1
# ...

# %%
#Selecting a column
data['Gender']
# Out:
# 0        FEMALE
# 1        FEMALE
# 2        FEMALE
# 3        FEMALE
# 4        FEMALE
#           ...
# 11340    FEMALE
# 11341    FEMALE
# 11342    FEMALE
# 11343    FEMALE
# 11344    FEMALE
# Name: Gender, Length: 11345, dtype: object

# %%
#Selecting multiple columns
data[['Gender','Ethnicity']]
# Out:
#        Gender                   Ethnicity
# 0      FEMALE  ASIAN AND PACIFIC ISLANDER
# 1      FEMALE  ASIAN AND PACIFIC ISLANDER
# 2      FEMALE  ASIAN AND PACIFIC ISLANDER
# 3      FEMALE  ASIAN AND PACIFIC ISLANDER
# 4      FEMALE  ASIAN AND PACIFIC ISLANDER
# ...       ...                         ...
# 11340  FEMALE          BLACK NON HISPANIC
# 11341  FEMALE          BLACK NON HISPANIC
# 11342  FEMALE          BLACK NON HISPANIC
# 11343  FEMALE          BLACK NON HISPANIC
# 11344  FEMALE          BLACK NON HISPANIC
#
# [11345 rows x 2 columns]

# %%
#Selecting multiple rows
data[4:8]
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# 5           2011  FEMALE  ASIAN AND PACIFIC ISLANDER           ISABELLA
# 6           2011  FEMALE  ASIAN AND PACIFIC ISLANDER            TIFFANY
# 7           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             ASHLEY
#
#    Count  Rank
# 4     75     5
# 5     67     6
# 6     54     7
# 7     52     8

# %%
#We are using the index/label here. It selects the data you want using the index
data.loc[[8,9]]
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 8           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              FIONA
# 9           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             ANGELA
#
#    Count  Rank
# 8     48     9
# 9     47    10

# %%
new = data.loc[[8,9]]

# %%
new
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 8           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              FIONA
# 9           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             ANGELA
#
#    Count  Rank
# 8     48     9
# 9     47    10

# %%
new['Gender']
# Out:
# 8    FEMALE
# 9    FEMALE
# Name: Gender, dtype: object

# %%
new = data.loc[[8,9,78,90]][['Gender','Count']]
# Out:
#     Gender  Count
# 8   FEMALE     48
# 9   FEMALE     47
# 78  FEMALE     17
# 90  FEMALE     15

# %%
#Here we are using the index only
data.iloc[0:3,2:4]
# Out:
#                     Ethnicity Child's First Name
# 0  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2  ASIAN AND PACIFIC ISLANDER              EMILY

# %%
data.iloc[0:4,:]
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
#
#    Count  Rank
# 0    119     1
# 1    106     2
# 2     93     3
# 3     89     4

# %%
data.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
#
#    Count  Rank
# 0    119     1
# 1    106     2
# 2     93     3
# 3     89     4
# 4     75     5

# %%
data.head(10)
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# 5           2011  FEMALE  ASIAN AND PACIFIC ISLANDER           ISABELLA
# 6           2011  FEMALE  ASIAN AND PACIFIC ISLANDER            TIFFANY
# 7           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             ASHLEY
# 8           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              FIONA
# 9           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             ANGELA
#
#    Count  Rank
# 0    119     1
# 1    106     2
# 2     93     3
# 3     89     4
# 4     75     5
# 5     67     6
# 6     54     7
# 7     52     8
# 8     48     9
# ...

# %%
data.tail()
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 11340           2016  FEMALE  BLACK NON HISPANIC            Saniyah     10
# 11341           2016  FEMALE  BLACK NON HISPANIC               Skye     10
# 11342           2016  FEMALE  BLACK NON HISPANIC              Tiana     10
# 11343           2016  FEMALE  BLACK NON HISPANIC             Violet     10
# 11344           2016  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 11340    43
# 11341    43
# 11342    43
# 11343    43
# 11344    43

# %%
data.sample(5)
# Out:
#       Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 684            2011  FEMALE  WHITE NON HISPANIC           VICTORIA     84
# 5849           2014  FEMALE            HISPANIC             Amelia     60
# 4440           2013  FEMALE  WHITE NON HISPANIC            Arianna     33
# 3423           2012    MALE            HISPANIC             DENZEL     14
# 9776           2016  FEMALE            HISPANIC              Skyla     14
#
#       Rank
# 684     26
# 5849    33
# 4440    59
# 3423    96
# 9776    70

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11345 entries, 0 to 11344
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year of Birth       11345 non-null  int64
#  1   Gender              11345 non-null  object
#  2   Ethnicity           11345 non-null  object
#  3   Child's First Name  11345 non-null  object
#  4   Count               11345 non-null  int64
#  5   Rank                11345 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 531.9+ KB

# %%
data.describe()
# Out:
#        Year of Birth         Count          Rank
# count   11345.000000  11345.000000  11345.000000
# mean     2013.552578     32.836844     57.656765
# std         1.746367     36.981866     25.186882
# min      2011.000000     10.000000      1.000000
# 25%      2012.000000     13.000000     38.000000
# 50%      2014.000000     20.000000     59.000000
# 75%      2015.000000     35.000000     79.000000
# max      2016.000000    387.000000    102.000000

# %%
data.dtypes
# Out:
# Year of Birth          int64
# Gender                object
# Ethnicity             object
# Child's First Name    object
# Count                  int64
# Rank                   int64
# dtype: object

# %%
#shows if there are missing values or not by displaying 'True' or 'False'
data.isnull()
# Out:
#        Year of Birth  Gender  Ethnicity  Child's First Name  Count   Rank
# 0              False   False      False               False  False  False
# 1              False   False      False               False  False  False
# 2              False   False      False               False  False  False
# 3              False   False      False               False  False  False
# 4              False   False      False               False  False  False
# ...              ...     ...        ...                 ...    ...    ...
# 11340          False   False      False               False  False  False
# 11341          False   False      False               False  False  False
# 11342          False   False      False               False  False  False
# 11343          False   False      False               False  False  False
# 11344          False   False      False               False  False  False
#
# [11345 rows x 6 columns]

# %%
#Gives the sum of the the missing values
data.isnull().sum()
# Out:
# Year of Birth         0
# Gender                0
# Ethnicity             0
# Child's First Name    0
# Count                 0
# Rank                  0
# dtype: int64

# %%
data1 = pd.read_csv('/content/Loan_prediction_dataset (1).csv')
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#data.isna() is the same as data.isnull()

# %%
data1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data1['Gender'].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
#Using the mode method it shows the gender that is occuring the most, this appears with the index
data1['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
#Here we are trying to display our value withouth the index in front,
# so we index out male, this automatically removes the index in front and displays "male"
data1['Gender'].mode()[0]
# Out:
# 'Male'

# %%
#Having 'Male' as the most occuring gender entry, we assume that the null values should be replaced with 'male'
data1['Gender'].fillna('Male')
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
data1['Gender'].fillna(data1['Gender'].mode()[0])
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
#This is still a method of trying to replace the null values with 'Male', which is the most occuring gender entry
#Note that before this changes reflect in your data set, you have to reassign the entire operation into a variable name indexing the column name
data1['Gender'] = data1['Gender'].fillna(data1['Gender'].mode()[0])
data1['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
#In this case we are replacing the null values with 0
data1['Gender'].fillna(0)
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
data1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data1.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#START
#to drop rows
new_data = data1.dropna(axis = 0)

# %%
#any row that has a null value, drop.
new_data = data1.dropna(axis = 0, how = 'any')

# %%
#any row that has the entire value as null, drop.
new_data = data1.dropna(axis = 0, how = 'all')

# %%
#to drop columns
new_data = data1.dropna(axis = 1)

# %%
new_data = data1.dropna(axis = 1, how = 'any')

# %%
new_data = data1.dropna(axis = 1, how = 'all')

# %%
#specifying the column, which is going to drop the entire row once a null value is identified in the specified column
new_data = data1.dropna(axis = 0, subset = ['LoanAmount'])

# %%
new_data = data1.dropna(axis = 0, subset = ['LoanAmount','Credit_History'])

# %%
# This parameter allows you to specify the minimum number of non-null values required to keep a row or column.
new_data = data1.dropna(axis = 0, thresh = 13)

# %%
print(data1.shape)
print(new_data.shape)
# Out:
# (614, 13)
# (492, 13)

# %%
#OUTLIERS

# %%
from scipy import stats
import numpy as np

# %%
#This line of code is used to select only numbers
a = data1.select_dtypes('number')
#a = data.select_dtype(int)
#a = data.select_dtype(float)
#a = data.select_dtype('object')

# %%
stats.zscore(a,axis=1)
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                NaN                NaN         NaN               NaN
# 1           1.901177           0.111731   -0.691337         -0.556328
# 2           1.986932          -0.588371   -0.531714         -0.279335
# 3           1.314720           1.117327   -0.846067         -0.635515
# 4           1.996875          -0.552544   -0.492633         -0.399579
# ..               ...                ...         ...               ...
# 609         1.986039          -0.592539   -0.529409         -0.272440
# 610         1.998342          -0.533656   -0.508990         -0.422657
# 611         1.998607          -0.491227   -0.487095         -0.453079
# 612         1.997985          -0.545448   -0.482726         -0.424699
# 613         1.994584          -0.567549   -0.493195         -0.366291
#
#      Credit_History
# 0               NaN
# 1         -0.765242
# 2         -0.587513
# 3         -0.950465
# ...

# %%
#the outliers are represented with NaN in the dataset
a[(np.abs(stats.zscore(a,axis=1)) < 3)]
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                NaN                NaN         NaN               NaN
# 1             4583.0             1508.0       128.0             360.0
# 2             3000.0                0.0        66.0             360.0
# 3             2583.0             2358.0       120.0             360.0
# 4             6000.0                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609           2900.0                0.0        71.0             360.0
# 610           4106.0                0.0        40.0             180.0
# 611           8072.0              240.0       253.0             360.0
# 612           7583.0                0.0       187.0             360.0
# 613           4583.0                0.0       133.0             360.0
#
#      Credit_History
# 0               NaN
# 1               1.0
# 2               1.0
# 3               1.0
# ...

# %%
#so you reassign the result back to a
a = a[(np.abs(stats.zscore(a,axis=1)) < 3)]

# %%
#This is just to change the data type
data['column_name'] = data['column_name'].astype(str)

# %%
data1 = data1.fillna('Single')

# %%
#x simply means each of the rows for the Married column, find the length. A new column is created named Length of married
data1['Length of Married'] = data1['Married'].apply(lambda x: len(x))

# %%
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0               5849                0.0     Single            360.0
# ...

# %%
data.to_csv("cleaned_data.csv", index=False)
