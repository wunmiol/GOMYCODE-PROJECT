# %%
class Account:
    def __init__(self, account_number, account_balance, account_holder):
        self.account_number = account_number
        self.account_balance = account_balance
        self.account_holder = account_holder
    def deposit(self, amount):
        self.account_balance = self.account_balance + amount
        return self.account_balance
    def withdrawal(self, amount):
        if self.account_balance > amount:
            self.account_balance = self.account_balance - amount
            return self.account_balance
    def check_balance(self):
        return self.account_balance

# %%
customer1 = Account(2209058943, 5000, 'Adewunmi Pelumi')
customer1.deposit(2000)
customer1.withdrawal(1000)
customer1.check_balance()
# Out:
# 6000

# %%
#INSTANCE 2
my_account = Account(2707865433, 9000, 'Richie Jane')
my_account.deposit(1000)
my_account.withdrawal(2000)
my_account.check_balance()
# Out:
# 8000
