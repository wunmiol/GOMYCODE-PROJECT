# %%
print("Welcome to Python Pizza Deliveries")
size = input("What size pizza would you like? : \nSmall : S\nMedium : M\nLarge : L ")
add_pepperoni = input("Do you want pepperoni on your pizza? (yes, no): ")
extra_cheese = input("Do you want extra cheese on your pizza? (yes, no): ")
bill = 0

#Logical Part
if size == "Small":
    bill = bill + 15
elif size == "Medium":
    bill = bill + 20
elif size == "Large":
    bill = bill + 25
else :
    print("choose a valid size")


if add_pepperoni == "Yes" and size == "S":
    bill = bill + 2
elif add_pepperoni == "Yes" and size == 'M' or 'L':
    bill = bill + 3
else :
    print("Not good")


if extra_cheese == "Yes":
    bill == bill + 1
    print('Your total bill is' ,bill)
else:
    print('Your total bill is' ,bill)
# Out:
# Welcome to Python Pizza Deliveries
# What size pizza would you like? :
# Small : S
# Medium : M
# Large : L S
# Do you want pepperoni on your pizza? (yes, no): yes
# Do you want extra cheese on your pizza? (yes, no): no
# choose a valid size
# Your total is 3
