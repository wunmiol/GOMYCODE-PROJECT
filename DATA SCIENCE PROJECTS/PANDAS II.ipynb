# %%
#label enconder
import pandas as pd

# %%
df = pd.read_csv('/content/Loan_prediction_dataset (1).csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Gender'] = le.fit(df['Gender'])

# %%
df['Gender'] = le.fit_transform(df['Gender'])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002       1      No          0      Graduate            No
# 1    LP001003       1     Yes          1      Graduate            No
# 2    LP001005       1     Yes          0      Graduate           Yes
# 3    LP001006       1     Yes          0  Not Graduate            No
# 4    LP001008       1      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978       0      No          0      Graduate            No
# 610  LP002979       1     Yes         3+      Graduate            No
# 611  LP002983       1     Yes          1      Graduate            No
# 612  LP002984       1     Yes          2      Graduate            No
# 613  LP002990       0      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Using a dictionary to encode
to_change = {'No':5, 'Yes':9}
df['Self_Employed']= df['Self_Employed'].replace(to_change)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education  Self_Employed  \
# 0    LP001002       1      No          0      Graduate            5.0
# 1    LP001003       1     Yes          1      Graduate            5.0
# 2    LP001005       1     Yes          0      Graduate            9.0
# 3    LP001006       1     Yes          0  Not Graduate            5.0
# 4    LP001008       1      No          0      Graduate            5.0
# ..        ...     ...     ...        ...           ...            ...
# 609  LP002978       0      No          0      Graduate            5.0
# 610  LP002979       1     Yes         3+      Graduate            5.0
# 611  LP002983       1     Yes          1      Graduate            5.0
# 612  LP002984       1     Yes          2      Graduate            5.0
# 613  LP002990       0      No          0      Graduate            9.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#one hot endocing principle
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
ohe.fit_transform([df['Married']])
# Out:
# <1x614 sparse matrix of type '<class 'numpy.float64'>'
# 	with 614 stored elements in Compressed Sparse Row format>

# %%
#To check for duplication within the columns
df.duplicated().any()
df['Education'].duplicated().any()

# %%
#To drop the duplicates
df.drop_duplicates()
#To reassign the operation you just performed back into the dataset
df.drop_duplicates(inplace = True)

df.drop_duplicates(subset  = ['Education'] ,inplace = True)

# %%
#Correlation
import seaborn as sns
df.select_dtypes('number').corr()
sns.heatmap(df.select_dtypes('number').corr(), annot = True)
# Out:
# <Axes: >

# %%
# !pip install pandas-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.9/357.9 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 12.5 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=aa70702e5e312f3366d568b60d7c217d5051c5bc1c2bf8278b98907a1e00ef95
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.1
#     Uninstalling seaborn-0.13.1:
# ...

# %%
from ydata_profiling import ProfileReport
# Generate the profile report
profile = ProfileReport(df, title='Pandas Profiling Report')

# Display the report
profile.to_notebook_iframe()
# Or generate an HTML report
profile.to_file("loanReport.html")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
