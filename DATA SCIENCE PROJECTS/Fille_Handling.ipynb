# %%
import numpy as np
data = np.genfromtxt('/content/Loan_prediction_dataset.csv', delimiter =',', dtype = str)

# %%
np.mean(data[1:, -5].astype(float))
# Out:
# 141.16612377850163

# %%
np.median(data[1:, -5].astype(float))
# Out:
# 125.0

# %%
np.std(data[1:, -5].astype(float))
# Out:
# 88.2686624330009
