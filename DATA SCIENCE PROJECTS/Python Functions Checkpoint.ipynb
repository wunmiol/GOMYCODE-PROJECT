# %%
def add(num1, num2):
  return num1 + num2

def subtract(num1, num2):
  return num1 - num2

def multiply(num1, num2):
  return num1 * num2

def divide(num1, num2):
  if num2 == 0:
    return "Error: Division by zero"
  else:
    return num1/ num2

operations = {
    '+': add,
    '-': subtract,
    '*': multiply,
    '/': divide
}


def calculator():
  while True:
    num1= int(input('Enter first number:'))
    if num1 is not

    operator_input=input('Enter an operation:')
    if operator_input not in operations:
      print("Invalid operation. Please choose from", list(operations.keys()))
      continue

    num2= int(input('Enter second number:'))

    calculation_function = operations[operator_input]
    answer = calculation_function(num1, num2)
    print(f"{num1} {operator_input} {num2} = {answer}")

    option = input('Do you want to continue with this result (Yes/No)? ').lower()
    if option == 'yes':
      num1 = answer
    elif option == 'no':
      break
    else:
      print("Invalid option. Please choose 'Yes' or 'No'.")

# %%
calculator()
# Out:
# Enter first number:4
# Enter an operation:+
# Enter second number:5
# 4 + 5 = 9
# Do you want to continue with this result (Yes/No)? yes
# Enter first number:4
# Enter an operation:+4
# Invalid operation. Please choose from ['+', '-', '*', '/']
# Enter first number:4
# Enter an operation:+
# Enter second number:4
# 4 + 4 = 8
# Do you want to continue with this result (Yes/No)? no
