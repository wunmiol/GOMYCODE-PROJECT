# %%
import pandas as pd

# %%
data = pd.read_csv('/content/car_prices.csv')
data
# Out:
#                         car_id    price fuel type  gear type           Make  \
# 0     icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic         Toyota
# 1     ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic          Acura
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic          Acura
# 3     7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e  4160000    Petrol  Automatic           Ford
# ...                        ...      ...       ...        ...            ...
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5  1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q  1890000    Petrol  Automatic  Mercedes-Benz
# 3719  g5szhuHeXu2djH1Z2be22G7E  1155000    Petrol  Automatic         Toyota
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr  1260000    Petrol  Automatic         Toyota
# 3721  fSUvulLwnXYlc1muFsrjrsAR  1872000    Petrol  Automatic          Honda
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_id               3722 non-null   object
#  1   price                3722 non-null   int64
#  2   fuel type            3721 non-null   object
#  3   gear type            3720 non-null   object
#  4   Make                 3722 non-null   object
#  5   Model                3722 non-null   object
#  6   Year of manufacture  3722 non-null   int64
#  7   Colour               3717 non-null   object
#  8   Condition            3722 non-null   object
#  9   Mileage              3663 non-null   float64
#  10  Engine Size          3661 non-null   float64
#  11  Selling Condition    3722 non-null   object
#  12  Bought Condition     3722 non-null   object
#  13  car                  1767 non-null   object
#  14  Trim                 879 non-null    object
# ...

# %%
data.describe()
# Out:
#               price  Year of manufacture       Mileage   Engine Size  \
# count  3.722000e+03          3722.000000  3.663000e+03  3.661000e+03
# mean   4.514644e+06          2008.145889  1.949841e+05  1.108062e+04
# std    4.297012e+06             4.205670  1.395755e+05  1.091127e+05
# min    5.500000e+05          1979.000000  1.000000e+00  1.800000e+02
# 25%    2.310000e+06          2005.000000  1.173945e+05  2.000000e+03
# 50%    3.360000e+06          2008.000000  1.762900e+05  2.500000e+03
# 75%    5.036250e+06          2011.000000  2.453815e+05  3.500000e+03
# max    6.240000e+07          2022.000000  2.456318e+06  3.500000e+06
#
#             Seats  Number of Cylinders  Horse Power
# count  788.000000           826.000000   755.000000
# mean     5.285533             5.157385   208.831788
# std      0.800853             1.202795    70.940925
# min      2.000000             4.000000    83.000000
# 25%      5.000000             4.000000   158.000000
# ...

# %%
data.isnull().sum()
# Out:
# car_id                    0
# price                     0
# fuel type                 1
# gear type                 2
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    5
# Condition                 0
# Mileage                  59
# Engine Size              61
# Selling Condition         0
# Bought Condition          0
# car                    1955
# Trim                   2843
# Drivetrain             2884
# Seats                  2934
# Number of Cylinders    2896
# Horse Power            2967
# Registered city        1821
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (3120, 20)

# %%
data.isnull().sum()
# Out:
# car_id                    0
# price                     0
# fuel type                 1
# gear type                 2
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    5
# Condition                 0
# Mileage                  51
# Engine Size              50
# Selling Condition         0
# Bought Condition          0
# car                    1643
# Trim                   2378
# Drivetrain             2418
# Seats                  2458
# Number of Cylinders    2425
# Horse Power            2485
# Registered city        1531
# dtype: int64

# %%
#The thresh is 70%
data.isnull().sum() / 3120 * 100
# Out:
# car_id                  0.000000
# price                   0.000000
# fuel type               0.032051
# gear type               0.064103
# Make                    0.000000
# Model                   0.000000
# Year of manufacture     0.000000
# Colour                  0.160256
# Condition               0.000000
# Mileage                 1.634615
# Engine Size             1.602564
# Selling Condition       0.000000
# Bought Condition        0.000000
# car                    52.660256
# Trim                   76.217949
# Drivetrain             77.500000
# Seats                  78.782051
# Number of Cylinders    77.724359
# Horse Power            79.647436
# Registered city        49.070513
# dtype: float64

# %%
#1-What is the shape of the data
data.shape
# Out:
# (3120, 20)

# %%
#2-What columns are numeric
data.select_dtypes('number').columns.to_list()
# Out:
# ['price',
#  'Year of manufacture',
#  'Mileage',
#  'Engine Size',
#  'Seats',
#  'Number of Cylinders',
#  'Horse Power']

# %%
#3-What columns are non-numeric
data.select_dtypes('object').columns.to_list()
# Out:
# ['car_id',
#  'fuel type',
#  'gear type',
#  'Make',
#  'Model',
#  'Colour',
#  'Condition',
#  'Selling Condition',
#  'Bought Condition',
#  'car',
#  'Trim',
#  'Drivetrain',
#  'Registered city']

# %%
#4-How many null values do we have in each column
data.isnull().sum()
# Out:
# car_id                    0
# price                     0
# fuel type                 1
# gear type                 2
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    5
# Condition                 0
# Mileage                  51
# Engine Size              50
# Selling Condition         0
# Bought Condition          0
# car                    1643
# Trim                   2378
# Drivetrain             2418
# Seats                  2458
# Number of Cylinders    2425
# Horse Power            2485
# Registered city        1531
# dtype: int64

# %%
#5-What is the total number of null values in the data
data.isnull().sum().sum()
# Out:
# 15447

# %%
#6-Do we have duplicates in the data and how much
data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# 0

# %%
#7-Is there any column that we probably need to drop,drop such columns.
#The thresh is 70%
data.isnull().sum() / 3120 * 100
# Out:
# car_id                  0.000000
# price                   0.000000
# fuel type               0.032051
# gear type               0.064103
# Make                    0.000000
# Model                   0.000000
# Year of manufacture     0.000000
# Colour                  0.160256
# Condition               0.000000
# Mileage                 1.634615
# Engine Size             1.602564
# Selling Condition       0.000000
# Bought Condition        0.000000
# car                    52.660256
# Trim                   76.217949
# Drivetrain             77.500000
# Seats                  78.782051
# Number of Cylinders    77.724359
# Horse Power            79.647436
# Registered city        49.070513
# dtype: float64

# %%
data['car'].value_counts()
# Out:
# car
# SUV                     951
# Sedan                   321
# Truck                    35
# Hatchback                35
# Minivan                  30
# Coupe                    27
# Crossover                22
# Bus                      12
# Van                      11
# Station Wagon             8
# Pickup                    7
# Saloon                    7
# Convertible               5
# Pick-up Double Cabin      3
# MUV                       3
# Name: count, dtype: int64

# %%
#checking for the number of seat in a particular car type
data.query("car=='Truck'").isnull().sum()
# Out:
# car_id                  0
# price                   0
# fuel type               0
# gear type               0
# Make                    0
# Model                   0
# Year of manufacture     0
# Colour                  0
# Condition               0
# Mileage                 1
# Engine Size             1
# Selling Condition       0
# Bought Condition        0
# car                     0
# Trim                   24
# Drivetrain             25
# Seats                  26
# Number of Cylinders    24
# Horse Power            24
# Registered city        14
# dtype: int64

# %%
data.query("car=='Truck'")
# Out:
#                         car_id     price fuel type  gear type        Make  \
# 29    wQajIZxTeX1HPesmV2Se9wxb   7360000    Petrol  Automatic      Toyota
# 72    5czUputP1RHEgLGuCjntdtBQ   8984000    Petrol     Manual      Toyota
# 92    5B55rWY4OQkKslv4EIitkcMH  27040000    Petrol  Automatic      Toyota
# 239   oCwRkPwBxHHv3jeG1nLFqu5p  10400000    Petrol  Automatic      Toyota
# 301   oNwznEsMENocBOAghHWluMqw   4725000    Petrol  Automatic      Toyota
# 347   wI2h5RpnGdw13z0I1vy70R8n  11550000    Petrol  Automatic      Toyota
# 353   u1Z8cAEENdAntCswEdS3XhNC   3150000    Petrol  Automatic      Toyota
# 385   s4ET91pyDnON3NPCSxqt7ocQ   3150000    Petrol  Automatic      Toyota
# 462   dsPUlTTYOb6CvQ9y3GMJOStQ   6300000    Petrol  Automatic        Ford
# 509   dvZOHzObIVDPwAJB9KDCuDpn   3150000    Petrol  Automatic       Honda
# 534   ayy7s5KyLNHTHl8kCNye8m1O   6448000    Petrol  Automatic       Honda
# 688   htPAdmZZ42MQNBgnBjjD75eE   3150000    Petrol     Manual      Nissan
# ...

# %%
seat_mapping = {'SUV': 7}
data['Seats'] = data['Seats'].fillna(data['car'].map(seat_mapping))

# %%
data
# Out:
#                         car_id    price fuel type  gear type           Make  \
# 0     icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic         Toyota
# 1     ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic          Acura
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic          Acura
# 3     7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e  4160000    Petrol  Automatic           Ford
# ...                        ...      ...       ...        ...            ...
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5  1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q  1890000    Petrol  Automatic  Mercedes-Benz
# 3719  g5szhuHeXu2djH1Z2be22G7E  1155000    Petrol  Automatic         Toyota
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr  1260000    Petrol  Automatic         Toyota
# 3721  fSUvulLwnXYlc1muFsrjrsAR  1872000    Petrol  Automatic          Honda
#
# ...

# %%
data['Drivetrain'].fillna(data['Drivetrain'].mode()[0], inplace = True)

# %%
data['car'].fillna(data['car'].mode()[0], inplace = True)

# %%
data['Seats'].fillna(data['Seats'].median(), inplace = True)

# %%
data['Number of Cylinders'].fillna(data['Number of Cylinders'].median(), inplace = True)

# %%
data['Horse Power'].fillna(data['Horse Power'].median(), inplace = True)

# %%
data['Trim'].fillna(data['Trim'].mode()[0], inplace = True)

# %%
data['Registered city'].fillna(data['Registered city'].mode()[0], inplace = True)
