# %%
import pandas as pd

# %%
iris_data = pd.DataFrame({
    'SepalLength': [5.1, 4.9, None, 5.6, 5.0],
    'SepalWidth': [3.5, None, 3.0, 3.9, 3.4],
    'PetalLength': [1.4, 1.4, 1.3, None, 1.5],
    'PetalWidth': [0.2, 0.2, 0.2, None, 0.2],
    'Species': ['setosa', 'setosa', 'setosa', 'setosa', 'setosa']
})

# %%
iris_data
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         NaN          1.4         0.2  setosa
# 2          NaN         3.0          1.3         0.2  setosa
# 3          5.6         3.9          NaN         NaN  setosa
# 4          5.0         3.4          1.5         0.2  setosa

# %%
iris_data.dropna(inplace=True)

# %%
iris_data
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 4          5.0         3.4          1.5         0.2  setosa

# %%
import pandas as pd

# Sample DataFrame
data = {'Category': ['A', 'F', 'C', 'A', 'B','F','B']}
df = pd.DataFrame(data)

# Perform One-Hot Encoding
encoded_df = pd.get_dummies(df['Category'], prefix='Batch')

# Concatenate the encoded DataFrame with the original DataFrame
df_encoded = pd.concat([df, encoded_df], axis=1)

print(df_encoded)
# Out:
#   Category  Batch_A  Batch_B  Batch_C  Batch_F
# 0        A     True    False    False    False
# 1        F    False    False    False     True
# 2        C    False    False     True    False
# 3        A     True    False    False    False
# 4        B    False     True    False    False
# 5        F    False    False    False     True
# 6        B    False     True    False    False
