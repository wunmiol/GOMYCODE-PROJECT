# %%
import pandas as pd
# !pip install pandas-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.9/357.9 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 11.0 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=8aa375593f79e827e71cd9ee229b5b36351bd9d3bbbc35a57761d1386cd965f4
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.1
#     Uninstalling seaborn-0.13.1:
# ...

# %%
#Use pandas to read the file into a pandas Dataframe.
Education_Attainment = pd.read_csv('/content/EDUCATION_ATTAINMENT.csv')

# %%
#Display general information about the dataset.
Education_Attainment.head()
# Out:
#    Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# 0                0.669091                0.667214                0.651812
# 1                0.485879                0.480171                0.465510
# 2                0.516431                0.514233                0.502269
# 3                0.914294                0.903528                0.871690
# 4                0.876990                0.841497                0.762864
#
#    Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# 0                0.460899                0.458749                0.446925
# 1                0.267236                0.265735                0.257999
# 2                0.327775                0.326250                0.318003
# 3                0.853770                0.840792                0.810794
# 4                0.881265                0.854158                0.795892
#
# ...

# %%
#Run descriptive analysis on the dataset using the 'describe' function.
Education_Attainment.describe()
# Out:
#        Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.873886                0.861490                0.837509
# std                  0.162624                0.166895                0.176555
# min                  0.251917                0.244071                0.233274
# 25%                  0.831791                0.803131                0.757465
# 50%                  0.948926                0.935167                0.909587
# 75%                  0.984447                0.980112                0.971166
# max                  1.000000                1.000000                1.000000
#
#        Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.823849                0.812738                0.789965
# ...

# %%
#Use ydata-profiling to generate a report of the provided dataset.
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(Education_Attainment, title='Education Attainment Report')

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file(output_file='education.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Identify any other interesting patterns or insights in the dataset that you can discover through the ydata-profiling report.
