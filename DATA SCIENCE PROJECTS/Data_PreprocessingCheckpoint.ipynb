# %%
import pandas as pd
#Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'
data = pd.read_csv('/content/STEG_BILLING_HISTORY.csv')
client_0_bills = data.head(10)
client_0_bills

# %%
#What is the data type of the 'client_0_bills' variable ?
print(type(client_0_bills))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#How many rows and columns do we have in this dataset ?
data
#154545 rows × 16 columns
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 154540  train_Client_104149   2011-02-22          40         13270.0
# 154541  train_Client_104149   2008-10-20          40         13270.0
# 154542  train_Client_104149   2008-06-20          40         13270.0
# 154543  train_Client_104149   2008-06-20          11        110865.0
# 154544  train_Client_104149   2006-11-29          11        110865.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
#How many categorical features are present in the dataset ?
data.value_counts().sum()
#154389
# Out:
# 154389

# %%
#How much memory space does the dataset consume ?
data.info()
#memory usage: 18.9+ MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154545 entries, 0 to 154544
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   client_id             154545 non-null  object
#  1   invoice_date          154545 non-null  object
#  2   tarif_type            154545 non-null  int64
#  3   counter_number        154543 non-null  float64
#  4   counter_statue        154545 non-null  int64
#  5   counter_code          154545 non-null  int64
#  6   reading_remarque      154392 non-null  float64
#  7   counter_coefficient   154545 non-null  int64
#  8   consommation_level_1  154545 non-null  int64
#  9   consommation_level_2  154545 non-null  int64
#  10  consommation_level_3  154545 non-null  int64
#  11  consommation_level_4  154545 non-null  int64
#  12  old_index             154545 non-null  int64
#  13  new_index             154545 non-null  int64
# ...

# %%
#nspect the dataset for potential missing values.
data.isnull().sum()
# Out:
# client_id                 0
# invoice_date              0
# tarif_type                0
# counter_number            2
# counter_statue            0
# counter_code              0
# reading_remarque        153
# counter_coefficient       0
# consommation_level_1      0
# consommation_level_2      0
# consommation_level_3      0
# consommation_level_4      0
# old_index                 0
# new_index                 0
# months_number             1
# counter_type              1
# dtype: int64

# %%
data['reading_remarque'] = pd.to_numeric(data['reading_remarque'], errors='coerce')
data['reading_remarque'] = data['reading_remarque'].fillna(data['reading_remarque'].mean())

# %%
data.isnull().sum()
# Out:
# client_id               0
# invoice_date            0
# tarif_type              0
# counter_number          0
# counter_statue          0
# counter_code            0
# reading_remarque        0
# counter_coefficient     0
# consommation_level_1    0
# consommation_level_2    0
# consommation_level_3    0
# consommation_level_4    0
# old_index               0
# new_index               0
# months_number           0
# counter_type            1
# dtype: int64

# %%
#Select your strategy to handle missing values, and tell us why you had made that choice.
data['counter_number'].fillna(data['counter_number'].mode()[0], inplace = True)

# %%
data['months_number'].fillna(data['months_number'].mode()[0], inplace = True)

# %%
data['counter_type'].fillna(data['counter_type'].mode()[0], inplace = True)

# %%
#Run a descriptive analysis on numeric features (columns)
data.describe()
# Out:
#           tarif_type  counter_number  counter_statue   counter_code  \
# count  154545.000000    1.545450e+05   154545.000000  154545.000000
# mean       20.189647    9.487650e+10        0.040713     171.717105
# std        13.502728    1.411295e+12        0.368359     133.552184
# min         9.000000    0.000000e+00        0.000000       5.000000
# 25%        11.000000    1.199200e+05        0.000000       5.000000
# 50%        11.000000    5.021120e+05        0.000000     203.000000
# 75%        40.000000    1.125490e+06        0.000000     207.000000
# max        45.000000    2.738110e+13        5.000000     532.000000
#
#        reading_remarque  counter_coefficient  consommation_level_1  \
# count     154545.000000        154545.000000         154545.000000
# mean           7.314116             1.000013            406.729322
# std            1.359535             0.005087            609.896717
# min            6.000000             1.000000              0.000000
# ...

# %%
#Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
from sklearn.preprocessing import OneHotEncoder
transformed = OneHotEncoder()
transformed.fit_transform([data['counter_type']])
# Out:
# <1x154545 sparse matrix of type '<class 'numpy.float64'>'
# 	with 154545 stored elements in Compressed Sparse Row format>

# %%
data
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 154540  train_Client_104149   2011-02-22          40         13270.0
# 154541  train_Client_104149   2008-10-20          40         13270.0
# 154542  train_Client_104149   2008-06-20          40         13270.0
# 154543  train_Client_104149   2008-06-20          11        110865.0
# 154544  train_Client_104149   2006-11-29          11        110865.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
bill_select = data.query("client_id =='train_Client_0'")
bill_select
# Out:
#          client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0               0
# 1   train_Client_0   2013-03-29          11       1335667.0               0
# 2   train_Client_0   2015-03-23          11       1335667.0               0
# 3   train_Client_0   2015-07-13          11       1335667.0               0
# 4   train_Client_0   2016-11-17          11       1335667.0               0
# 5   train_Client_0   2017-07-17          11       1335667.0               0
# 6   train_Client_0   2018-12-07          11       1335667.0               0
# 7   train_Client_0   2019-03-19          11       1335667.0               0
# 8   train_Client_0   2011-07-22          11       1335667.0               0
# 9   train_Client_0   2011-11-22          11       1335667.0               0
# 10  train_Client_0   2008-11-25          11       1335667.0               0
# ...

# %%
bill_select = 'train_Client_0'
bill_select = data[data['client_id'] == client_id]
bill_select
# Out:
#          client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0               0
# 1   train_Client_0   2013-03-29          11       1335667.0               0
# 2   train_Client_0   2015-03-23          11       1335667.0               0
# 3   train_Client_0   2015-07-13          11       1335667.0               0
# 4   train_Client_0   2016-11-17          11       1335667.0               0
# 5   train_Client_0   2017-07-17          11       1335667.0               0
# 6   train_Client_0   2018-12-07          11       1335667.0               0
# 7   train_Client_0   2019-03-19          11       1335667.0               0
# 8   train_Client_0   2011-07-22          11       1335667.0               0
# 9   train_Client_0   2011-11-22          11       1335667.0               0
# 10  train_Client_0   2008-11-25          11       1335667.0               0
# ...

# %%
#Delete the 'counter_statue' feature from the Dataframe
del data['counter_statue']
